# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\corde\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\corde\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url =  "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city 

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() #inst

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather ["coord"]["lat"]
        city_lng = city_weather ["coord"]["lon"]
        city_max_temp = city_weather ["main"]["temp_max"]
        city_humidity = city_weather ["main"]["humidity"]
        city_clouds =  city_weather ["clouds"]["all"]
        city_wind =  city_weather ["wind"]["speed"]
        city_country = city_weather ["sys"]["country"]
        city_date = ["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isafjordur
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | saint croix
# Processing Record 4 of Set 1 | saquarema
# Processing Record 5 of Set 1 | utrik
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | posto fiscal rolim de moura
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | gaigeturi
# Processing Record 13 of Set 1 | klyuchi
# Processing Record 14 of Set 1 | banda aceh
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | sandakan
# Processing Record 17 of Set 1 | cajabamba
# Processing Record 18 of Set 1 | midvagur
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | nagqu
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | bandar abbas
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | edinburgh of the seven seas
# Processing Record 25 of Set 1 | sao joao da barra
# Processing Record 26 of Set 1 | ancud
# Processing Record 27 of Set 1 | lerwick
# Processing Record 28 of Set 1 | stanley
# Processing Record 29 of Set 1 | lihue
# Processing Record 30 of Set 1 | afaahiti
# Processing Record 31 of Set 1 | kailua-kona
# Processing Record 32 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | paramonga
# Processing Record 36 of Set 1 | whitehorse
# Processing Record 37 of Set 1 | baneh
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | ingeniero jacobacci
# Processing Record 40 of Set 1 | tabou
# Processing Record 41 of Set 1 | bilibino
# Processing Record 42 of Set 1 | camargo
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | nar'yan-mar
# Processing Record 45 of Set 1 | west island
# Processing Record 46 of Set 1 | badger
# Processing Record 47 of Set 1 | ostersund
# Processing Record 48 of Set 1 | ploudalmezeau
# Processing Record 49 of Set 1 | araguaina
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 0 of Set 2 | vila velha
# Processing Record 1 of Set 2 | alo
# Processing Record 2 of Set 2 | karratha
# Processing Record 3 of Set 2 | kapuskasing
# Processing Record 4 of Set 2 | fedorovka
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | alotau
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | papatowai
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | barabai
# Processing Record 11 of Set 2 | ar raqqah
# Processing Record 12 of Set 2 | xilin hot
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | kotkapura
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | akrehamn
# Processing Record 17 of Set 2 | port mathurin
# Processing Record 18 of Set 2 | pointe-noire
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | blackmans bay
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | mount isa
# Processing Record 23 of Set 2 | san pedro
# Processing Record 24 of Set 2 | tura
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | huaidian
# Processing Record 27 of Set 2 | 'ibri
# City not found. Skipping...
# Processing Record 28 of Set 2 | roma
# Processing Record 29 of Set 2 | ruteng
# Processing Record 30 of Set 2 | chernyshevskiy
# Processing Record 31 of Set 2 | susanville
# Processing Record 32 of Set 2 | tanout
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | uliastay
# Processing Record 35 of Set 2 | yeniseysk
# Processing Record 36 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 2 | patin-ay
# Processing Record 38 of Set 2 | faya-largeau
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | mossel bay
# Processing Record 41 of Set 2 | sisimiut
# Processing Record 42 of Set 2 | olonkinbyen
# Processing Record 43 of Set 2 | qarqaraly
# Processing Record 44 of Set 2 | crane
# Processing Record 45 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 2 | wailua homesteads
# Processing Record 47 of Set 2 | palikir - national government center
# Processing Record 48 of Set 2 | susuman
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 0 of Set 3 | yuzhno-kurilsk
# Processing Record 1 of Set 3 | aldan
# Processing Record 2 of Set 3 | bokoro
# Processing Record 3 of Set 3 | torres
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | newman
# Processing Record 6 of Set 3 | anadyr
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | riosucio
# Processing Record 9 of Set 3 | campo gallo
# Processing Record 10 of Set 3 | nova sintra
# Processing Record 11 of Set 3 | uturoa
# Processing Record 12 of Set 3 | turinskaya sloboda
# Processing Record 13 of Set 3 | fianarantsoa
# Processing Record 14 of Set 3 | invercargill
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | mlimba
# Processing Record 17 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 3 | taksimo
# Processing Record 19 of Set 3 | arquitecto tomas romero pereira
# Processing Record 20 of Set 3 | revda
# Processing Record 21 of Set 3 | chonchi
# Processing Record 22 of Set 3 | la'ie
# Processing Record 23 of Set 3 | senanga
# Processing Record 24 of Set 3 | tortoli
# Processing Record 25 of Set 3 | puerto natales
# Processing Record 26 of Set 3 | dilling
# Processing Record 27 of Set 3 | al hawatah
# Processing Record 28 of Set 3 | vorgashor
# Processing Record 29 of Set 3 | hawaiian paradise park
# Processing Record 30 of Set 3 | palmer
# Processing Record 31 of Set 3 | kegeyli shahar
# Processing Record 32 of Set 3 | tena
# Processing Record 33 of Set 3 | kone
# Processing Record 34 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | kristiansund
# Processing Record 37 of Set 3 | gwanda
# Processing Record 38 of Set 3 | dunda
# Processing Record 39 of Set 3 | divnogorsk
# Processing Record 40 of Set 3 | tofol
# Processing Record 41 of Set 3 | sept-iles
# Processing Record 42 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 43 of Set 3 | las lomitas
# Processing Record 44 of Set 3 | lata
# Processing Record 45 of Set 3 | pamukova
# Processing Record 46 of Set 3 | prainha
# Processing Record 47 of Set 3 | donduseni
# Processing Record 48 of Set 3 | remire-montjoly
# Processing Record 49 of Set 3 | jieshi
# Processing Record 0 of Set 4 | carnarvon
# Processing Record 1 of Set 4 | quellon
# Processing Record 2 of Set 4 | palasa
# Processing Record 3 of Set 4 | hovd
# Processing Record 4 of Set 4 | shahrak
# Processing Record 5 of Set 4 | qaqortoq
# Processing Record 6 of Set 4 | vila franca do campo
# Processing Record 7 of Set 4 | esquina
# Processing Record 8 of Set 4 | howard springs
# Processing Record 9 of Set 4 | mount pearl
# Processing Record 10 of Set 4 | jilib
# Processing Record 11 of Set 4 | bikenibeu village
# Processing Record 12 of Set 4 | mirny
# Processing Record 13 of Set 4 | haiku-pauwela
# Processing Record 14 of Set 4 | nanao
# Processing Record 15 of Set 4 | san pedro pochutla
# Processing Record 16 of Set 4 | williams lake
# Processing Record 17 of Set 4 | sogndal
# Processing Record 18 of Set 4 | sitka
# Processing Record 19 of Set 4 | skeldon
# Processing Record 20 of Set 4 | robertsport
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | yinchuan
# Processing Record 23 of Set 4 | qianzhou
# Processing Record 24 of Set 4 | kharp
# Processing Record 25 of Set 4 | margaret river
# Processing Record 26 of Set 4 | tarawa
# Processing Record 27 of Set 4 | phek
# Processing Record 28 of Set 4 | nova vicosa
# Processing Record 29 of Set 4 | kokopo
# Processing Record 30 of Set 4 | tromso
# Processing Record 31 of Set 4 | howrah
# Processing Record 32 of Set 4 | mawu
# Processing Record 33 of Set 4 | st. john's
# Processing Record 34 of Set 4 | saint-pierre
# Processing Record 35 of Set 4 | brookings
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | castillos
# Processing Record 38 of Set 4 | kosh-agach
# Processing Record 39 of Set 4 | chuarrancho
# Processing Record 40 of Set 4 | trairi
# Processing Record 41 of Set 4 | papao
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | alofi
# Processing Record 44 of Set 4 | kavaratti
# Processing Record 45 of Set 4 | ust-nera
# Processing Record 46 of Set 4 | port saint john's
# Processing Record 47 of Set 4 | volodarka
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | codrington
# Processing Record 0 of Set 5 | ulsteinvik
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | vadso
# Processing Record 3 of Set 5 | boyolangu
# Processing Record 4 of Set 5 | sao vicente
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | walvis bay
# Processing Record 7 of Set 5 | al-hamdaniya
# Processing Record 8 of Set 5 | swakopmund
# Processing Record 9 of Set 5 | suoyarvi
# Processing Record 10 of Set 5 | colonia
# Processing Record 11 of Set 5 | kingston
# Processing Record 12 of Set 5 | kargasok
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | punta arenas
# Processing Record 15 of Set 5 | karaidel'
# Processing Record 16 of Set 5 | puerto baquerizo moreno
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | totness
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | gulu
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | hillvue
# Processing Record 23 of Set 5 | nemuro
# Processing Record 24 of Set 5 | albany
# Processing Record 25 of Set 5 | eldorado
# Processing Record 26 of Set 5 | bardai
# Processing Record 27 of Set 5 | fale old settlement
# Processing Record 28 of Set 5 | lazaro cardenas
# Processing Record 29 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 5 | kourou
# Processing Record 31 of Set 5 | mende
# Processing Record 32 of Set 5 | akureyri
# Processing Record 33 of Set 5 | goure
# Processing Record 34 of Set 5 | peace river
# Processing Record 35 of Set 5 | valle de la pascua
# Processing Record 36 of Set 5 | yeed
# Processing Record 37 of Set 5 | gobabis
# Processing Record 38 of Set 5 | atafu village
# Processing Record 39 of Set 5 | lorengau
# Processing Record 40 of Set 5 | tra mhor
# Processing Record 41 of Set 5 | keflavik
# Processing Record 42 of Set 5 | gela
# Processing Record 43 of Set 5 | hadibu
# Processing Record 44 of Set 5 | kingscliff
# Processing Record 45 of Set 5 | myitkyina
# Processing Record 46 of Set 5 | oroqen zizhiqi
# Processing Record 47 of Set 5 | fort bragg
# Processing Record 48 of Set 5 | caiaponia
# Processing Record 49 of Set 5 | harstad
# Processing Record 0 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 6 | agadez
# Processing Record 2 of Set 6 | manokwari
# Processing Record 3 of Set 6 | emerald
# Processing Record 4 of Set 6 | letterkenny
# Processing Record 5 of Set 6 | aginskoye
# Processing Record 6 of Set 6 | penapolis
# Processing Record 7 of Set 6 | tazovsky
# Processing Record 8 of Set 6 | johnstown
# Processing Record 9 of Set 6 | pariaman
# Processing Record 10 of Set 6 | antalaha
# Processing Record 11 of Set 6 | kirakira
# Processing Record 12 of Set 6 | wickenburg
# Processing Record 13 of Set 6 | stornoway
# Processing Record 14 of Set 6 | huanuni
# Processing Record 15 of Set 6 | kalifornsky
# Processing Record 16 of Set 6 | luimneach
# Processing Record 17 of Set 6 | saipan
# Processing Record 18 of Set 6 | khorixas
# Processing Record 19 of Set 6 | east london
# Processing Record 20 of Set 6 | ulety
# Processing Record 21 of Set 6 | orlovskiy
# Processing Record 22 of Set 6 | porto novo
# Processing Record 23 of Set 6 | vozhega
# Processing Record 24 of Set 6 | tweed heads
# Processing Record 25 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 6 | ola
# Processing Record 27 of Set 6 | dryden
# Processing Record 28 of Set 6 | fort mcmurray
# Processing Record 29 of Set 6 | dawson creek
# Processing Record 30 of Set 6 | barao de cocais
# Processing Record 31 of Set 6 | harnai
# Processing Record 32 of Set 6 | ozernyy
# Processing Record 33 of Set 6 | taro
# Processing Record 34 of Set 6 | puerto armuelles
# Processing Record 35 of Set 6 | mil'kovo
# Processing Record 36 of Set 6 | touros
# Processing Record 37 of Set 6 | kiruna
# Processing Record 38 of Set 6 | tindouf
# Processing Record 39 of Set 6 | kez
# Processing Record 40 of Set 6 | schweizer-reneke
# Processing Record 41 of Set 6 | corner brook
# Processing Record 42 of Set 6 | erenhot
# Processing Record 43 of Set 6 | acarau
# Processing Record 44 of Set 6 | puerto el triunfo
# Processing Record 45 of Set 6 | tolanaro
# Processing Record 46 of Set 6 | ghadamis
# Processing Record 47 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 48 of Set 6 | tralee
# Processing Record 49 of Set 6 | novo aripuana
# Processing Record 0 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 7 | vilyuchinsk
# Processing Record 2 of Set 7 | manhumirim
# Processing Record 3 of Set 7 | thurso
# Processing Record 4 of Set 7 | oualidia
# City not found. Skipping...
# Processing Record 5 of Set 7 | udachny
# Processing Record 6 of Set 7 | ormara
# Processing Record 7 of Set 7 | guarapari
# Processing Record 8 of Set 7 | ulladulla
# Processing Record 9 of Set 7 | timimoun
# Processing Record 10 of Set 7 | belozersk
# Processing Record 11 of Set 7 | brooks
# Processing Record 12 of Set 7 | nejo
# Processing Record 13 of Set 7 | vorkuta
# Processing Record 14 of Set 7 | zhangjiagang
# Processing Record 15 of Set 7 | cadale
# Processing Record 16 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 17 of Set 7 | holualoa
# Processing Record 18 of Set 7 | szczecin
# Processing Record 19 of Set 7 | livingston
# Processing Record 20 of Set 7 | polyarnyy
# Processing Record 21 of Set 7 | perry
# Processing Record 22 of Set 7 | iguatemi
# Processing Record 23 of Set 7 | salinopolis
# Processing Record 24 of Set 7 | brisas de zicatela
# Processing Record 25 of Set 7 | cabedelo
# Processing Record 26 of Set 7 | sandnes
# Processing Record 27 of Set 7 | nizhneudinsk
# Processing Record 28 of Set 7 | cole harbour
# Processing Record 29 of Set 7 | konarka
# Processing Record 30 of Set 7 | magadan
# Processing Record 31 of Set 7 | bull savanna
# Processing Record 32 of Set 7 | horta
# Processing Record 33 of Set 7 | vredenburg
# City not found. Skipping...
# Processing Record 34 of Set 7 | aykhal
# Processing Record 35 of Set 7 | bure
# Processing Record 36 of Set 7 | bafoulabe
# Processing Record 37 of Set 7 | callao
# Processing Record 38 of Set 7 | santa rita
# Processing Record 39 of Set 7 | selfoss
# Processing Record 40 of Set 7 | berdigestyakh
# Processing Record 41 of Set 7 | miri
# Processing Record 42 of Set 7 | enewetak
# Processing Record 43 of Set 7 | turpan
# Processing Record 44 of Set 7 | al qusayr
# Processing Record 45 of Set 7 | melouza
# Processing Record 46 of Set 7 | manismata
# Processing Record 47 of Set 7 | beoumi
# Processing Record 48 of Set 7 | weno
# Processing Record 49 of Set 7 | taoudenni
# Processing Record 0 of Set 8 | east tamworth
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | oranjemund
# Processing Record 3 of Set 8 | constantia
# Processing Record 4 of Set 8 | smidovich
# Processing Record 5 of Set 8 | beidao
# Processing Record 6 of Set 8 | sola
# Processing Record 7 of Set 8 | saba
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | albert lea
# Processing Record 10 of Set 8 | black point
# Processing Record 11 of Set 8 | am djarass
# City not found. Skipping...
# Processing Record 12 of Set 8 | dudinka
# Processing Record 13 of Set 8 | yarmouth
# Processing Record 14 of Set 8 | goynuk
# Processing Record 15 of Set 8 | san clemente del tuyu
# Processing Record 16 of Set 8 | noshiro
# Processing Record 17 of Set 8 | sake
# Processing Record 18 of Set 8 | belyy yar
# Processing Record 19 of Set 8 | bengkulu
# Processing Record 20 of Set 8 | costa calma
# City not found. Skipping...
# Processing Record 21 of Set 8 | igrim
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | lagunillas
# Processing Record 24 of Set 8 | fuerte olimpo
# Processing Record 25 of Set 8 | ambodifotatra
# Processing Record 26 of Set 8 | las heras
# Processing Record 27 of Set 8 | yaren
# Processing Record 28 of Set 8 | santa cruz
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | eyl
# Processing Record 31 of Set 8 | lensk
# Processing Record 32 of Set 8 | happy valley-goose bay
# Processing Record 33 of Set 8 | toliara
# Processing Record 34 of Set 8 | lodwar
# Processing Record 35 of Set 8 | merritt
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | cidreira
# Processing Record 38 of Set 8 | zeya
# Processing Record 39 of Set 8 | iskateley
# Processing Record 40 of Set 8 | klaksvik
# Processing Record 41 of Set 8 | katsuura
# Processing Record 42 of Set 8 | vicuna
# Processing Record 43 of Set 8 | veinticinco de mayo
# Processing Record 44 of Set 8 | nuku'alofa
# Processing Record 45 of Set 8 | dakhla
# Processing Record 46 of Set 8 | reedsburg
# Processing Record 47 of Set 8 | meulaboh
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | piti village
# Processing Record 0 of Set 9 | taco pozo
# Processing Record 1 of Set 9 | amga
# Processing Record 2 of Set 9 | tadine
# Processing Record 3 of Set 9 | portland
# Processing Record 4 of Set 9 | bosobolo
# Processing Record 5 of Set 9 | santa marta
# Processing Record 6 of Set 9 | ares
# Processing Record 7 of Set 9 | sandefjord
# Processing Record 8 of Set 9 | la junta
# Processing Record 9 of Set 9 | assab
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | la sarre
# Processing Record 12 of Set 9 | murici
# Processing Record 13 of Set 9 | aasiaat
# Processing Record 14 of Set 9 | baiti
# Processing Record 15 of Set 9 | oros
# Processing Record 16 of Set 9 | al ghayzah
# Processing Record 17 of Set 9 | el calafate
# Processing Record 18 of Set 9 | ouellah
# City not found. Skipping...
# Processing Record 19 of Set 9 | muzayri'
# City not found. Skipping...
# Processing Record 20 of Set 9 | warrnambool
# Processing Record 21 of Set 9 | nagato
# Processing Record 22 of Set 9 | lockwood
# Processing Record 23 of Set 9 | eastham
# Processing Record 24 of Set 9 | razole
# Processing Record 25 of Set 9 | villa gesell
# Processing Record 26 of Set 9 | ivdel'
# Processing Record 27 of Set 9 | yunak
# Processing Record 28 of Set 9 | smithers
# Processing Record 29 of Set 9 | zaragoza
# Processing Record 30 of Set 9 | yalutorovsk
# Processing Record 31 of Set 9 | machico
# Processing Record 32 of Set 9 | mili
# Processing Record 33 of Set 9 | seogwipo
# City not found. Skipping...
# Processing Record 34 of Set 9 | margate
# Processing Record 35 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 36 of Set 9 | chinchilla
# Processing Record 37 of Set 9 | la passe
# Processing Record 38 of Set 9 | namdrik
# Processing Record 39 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 40 of Set 9 | gering
# Processing Record 41 of Set 9 | malanje
# Processing Record 42 of Set 9 | goulburn
# Processing Record 43 of Set 9 | taltal
# Processing Record 44 of Set 9 | puerto deseado
# Processing Record 45 of Set 9 | mayya
# Processing Record 46 of Set 9 | kambove
# Processing Record 47 of Set 9 | fredrikstad
# Processing Record 48 of Set 9 | indri
# Processing Record 49 of Set 9 | el matama
# Processing Record 0 of Set 10 | micheweni
# Processing Record 1 of Set 10 | padangsidempuan
# Processing Record 2 of Set 10 | arenapolis
# Processing Record 3 of Set 10 | oume
# Processing Record 4 of Set 10 | tyukhtet
# Processing Record 5 of Set 10 | egilsstadir
# Processing Record 6 of Set 10 | skiathos
# Processing Record 7 of Set 10 | victorica
# Processing Record 8 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 9 of Set 10 | bousse
# Processing Record 10 of Set 10 | chinna salem
# Processing Record 11 of Set 10 | mariental
# Processing Record 12 of Set 10 | queenstown
# Processing Record 13 of Set 10 | treasure island
# Processing Record 14 of Set 10 | myrina
# Processing Record 15 of Set 10 | nadym
# Processing Record 16 of Set 10 | ventspils
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | khilok
# Processing Record 19 of Set 10 | galle
# Processing Record 20 of Set 10 | namibe
# Processing Record 21 of Set 10 | pointe aux piments
# Processing Record 22 of Set 10 | quincy
# Processing Record 23 of Set 10 | fort st. john
# Processing Record 24 of Set 10 | elmina
# Processing Record 25 of Set 10 | luanda
# Processing Record 26 of Set 10 | lamu
# Processing Record 27 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 28 of Set 10 | armacao de buzios
# Processing Record 29 of Set 10 | erwin
# Processing Record 30 of Set 10 | tidjikja
# Processing Record 31 of Set 10 | nogliki
# Processing Record 32 of Set 10 | praia da vitoria
# Processing Record 33 of Set 10 | ta`u
# Processing Record 34 of Set 10 | verkhov'ye
# Processing Record 35 of Set 10 | mariehamn
# Processing Record 36 of Set 10 | kayangel
# Processing Record 37 of Set 10 | korla
# Processing Record 38 of Set 10 | ramshir
# Processing Record 39 of Set 10 | federacion
# Processing Record 40 of Set 10 | ta'izz
# Processing Record 41 of Set 10 | khromtau
# Processing Record 42 of Set 10 | ketchikan
# Processing Record 43 of Set 10 | basco
# Processing Record 44 of Set 10 | aktau
# Processing Record 45 of Set 10 | minas de marcona
# Processing Record 46 of Set 10 | san patricio
# Processing Record 47 of Set 10 | kyaikkami
# Processing Record 48 of Set 10 | the pas
# Processing Record 49 of Set 10 | mary
# Processing Record 0 of Set 11 | san antonio de pale
# Processing Record 1 of Set 11 | huai mek
# Processing Record 2 of Set 11 | wotje
# Processing Record 3 of Set 11 | barra da estiva
# Processing Record 4 of Set 11 | atasu
# Processing Record 5 of Set 11 | chabahar
# Processing Record 6 of Set 11 | chinde
# Processing Record 7 of Set 11 | keningau
# Processing Record 8 of Set 11 | hammerfest
# Processing Record 9 of Set 11 | constitucion
# Processing Record 10 of Set 11 | pauini
# Processing Record 11 of Set 11 | mugia
# Processing Record 12 of Set 11 | makokou
# Processing Record 13 of Set 11 | cartagena
# Processing Record 14 of Set 11 | plettenberg bay
# Processing Record 15 of Set 11 | marrakesh
# Processing Record 16 of Set 11 | ruidoso
# Processing Record 17 of Set 11 | santa elena de uairen
# Processing Record 18 of Set 11 | decazeville
# Processing Record 19 of Set 11 | ponta delgada
# Processing Record 20 of Set 11 | san matias
# Processing Record 21 of Set 11 | qui nhon
# Processing Record 22 of Set 11 | port isabel
# Processing Record 23 of Set 11 | tomatlan
# Processing Record 24 of Set 11 | camenca
# Processing Record 25 of Set 11 | inirida
# Processing Record 26 of Set 11 | vikulovo
# Processing Record 27 of Set 11 | shubarshi
# Processing Record 28 of Set 11 | parauapebas
# Processing Record 29 of Set 11 | ratnagiri
# Processing Record 30 of Set 11 | ciudad real
# Processing Record 31 of Set 11 | tbeng meanchey
# Processing Record 32 of Set 11 | naze
# Processing Record 33 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 34 of Set 11 | pijijiapan
# Processing Record 35 of Set 11 | tsiombe
# Processing Record 36 of Set 11 | beysehir
# Processing Record 37 of Set 11 | tual
# Processing Record 38 of Set 11 | north bend
# Processing Record 39 of Set 11 | sadovoye
# Processing Record 40 of Set 11 | as sulayyil
# Processing Record 41 of Set 11 | silver city
# Processing Record 42 of Set 11 | arno
# Processing Record 43 of Set 11 | mont-dore
# Processing Record 44 of Set 11 | celanova
# Processing Record 45 of Set 11 | verkh-chebula
# Processing Record 46 of Set 11 | as samawah
# Processing Record 47 of Set 11 | sao paulo de olivenca
# Processing Record 48 of Set 11 | labrador city
# Processing Record 49 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 0 of Set 12 | bhamo
# Processing Record 1 of Set 12 | eureka
# Processing Record 2 of Set 12 | calingasta
# Processing Record 3 of Set 12 | leava
# Processing Record 4 of Set 12 | severo-yeniseyskiy
# Processing Record 5 of Set 12 | suva
# Processing Record 6 of Set 12 | darwin
# Processing Record 7 of Set 12 | bahia honda
# Processing Record 8 of Set 12 | humaita
# Processing Record 9 of Set 12 | muisne
# Processing Record 10 of Set 12 | prince albert
# Processing Record 11 of Set 12 | bamboo flat
# Processing Record 12 of Set 12 | keetmanshoop
# Processing Record 13 of Set 12 | mejit
# Processing Record 14 of Set 12 | kerikeri
# Processing Record 15 of Set 12 | bushland beach
# City not found. Skipping...
# Processing Record 16 of Set 12 | rosarito
# Processing Record 17 of Set 12 | beberibe
# Processing Record 18 of Set 12 | sinop
# Processing Record 19 of Set 12 | wuhu
# Processing Record 20 of Set 12 | lompoc
# Processing Record 21 of Set 12 | jiagedaqi
# Processing Record 22 of Set 12 | bajna
# Processing Record 23 of Set 12 | ust'-ilimsk
# Processing Record 24 of Set 12 | paita
# Processing Record 25 of Set 12 | qingyuan
# Processing Record 26 of Set 12 | abraham's bay
# City not found. Skipping...
# Processing Record 27 of Set 12 | renon - ritten
# Processing Record 28 of Set 12 | nadbai
# Processing Record 29 of Set 12 | isoka
# Processing Record 30 of Set 12 | menaka
# Processing Record 31 of Set 12 | phayakkhaphum phisai
# Processing Record 32 of Set 12 | arraial do cabo
# Processing Record 33 of Set 12 | eydhafushi
# Processing Record 34 of Set 12 | tongouson
# Processing Record 35 of Set 12 | mata-utu
# Processing Record 36 of Set 12 | maun
# Processing Record 37 of Set 12 | mabaruma
# Processing Record 38 of Set 12 | beyla
# Processing Record 39 of Set 12 | zemetchino
# Processing Record 40 of Set 12 | salekhard
# Processing Record 41 of Set 12 | arkhangel'sk
# Processing Record 42 of Set 12 | tamandare
# Processing Record 43 of Set 12 | ivolginsk
# Processing Record 44 of Set 12 | veroia
# Processing Record 45 of Set 12 | beira
# Processing Record 46 of Set 12 | tecolots
# Processing Record 47 of Set 12 | antsiranana
# Processing Record 48 of Set 12 | little cayman
# City not found. Skipping...
# Processing Record 49 of Set 12 | rasony
# Processing Record 0 of Set 13 | rochester
# Processing Record 1 of Set 13 | tobelo
# Processing Record 2 of Set 13 | primero de mayo
# Processing Record 3 of Set 13 | mana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   isafjordur  66.0755  -23.1240     -2.70        92         100        8.64
# 1     waitangi -43.9535 -176.5597     13.79        98          85        2.24
# 2  saint croix  17.7397  -64.7388     26.25        89          75        2.06
# 3    saquarema -22.9200  -42.5103     22.54        92         100        6.34
# 4        utrik  11.2278  169.8474     28.40        74           7        6.31
#
#   Country  Date
# 0      IS  [dt]
# 1      NZ  [dt]
# 2      VI  [dt]
# 3      BR  [dt]
# 4      MH  [dt]

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         isafjordur  66.0755  -23.1240     -2.70        92         100
# 1           waitangi -43.9535 -176.5597     13.79        98          85
# 2        saint croix  17.7397  -64.7388     26.25        89          75
# 3          saquarema -22.9200  -42.5103     22.54        92         100
# 4              utrik  11.2278  169.8474     28.40        74           7
#
#          Wind Speed Country    Date
# City_ID
# 0              8.64      IS  ['dt']
# 1              2.24      NZ  ['dt']
# 2              2.06      VI  ['dt']
# 3              6.34      BR  ['dt']
# 4              6.31      MH  ['dt']

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolor='black', linewidth=0.5)

# Get today's date
today_date = datetime.now().strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Max Temp ({today_date})')
plt.ylabel("Max Temp (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolor='black', linewidth=0.5)

# Get today's date
today_date = datetime.now().strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Humidity ({today_date})')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor='black', linewidth=0.5)

# Get today's date
today_date = datetime.now().strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Cloudiness ({today_date})')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolor='black', linewidth=0.5)

# Get today's date
today_date = datetime.now().strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.title(f'City Latitude vs Wind Speed ({today_date})')
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
   
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
  
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r^2-value is: {rvalue**2}")

     # Set the title of the plot
    plt.title(f"Linear Regression of {title} vs. Latitude")
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere = city_data_df[city_data_df['Lat'] >= 0]


# Display sample data
northern_hemisphere.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          isafjordur  66.0755  -23.1240     -2.70        92         100
# 2         saint croix  17.7397  -64.7388     26.25        89          75
# 4               utrik  11.2278  169.8474     28.40        74           7
# 7        longyearbyen  78.2186   15.6401     -5.09        50          75
# 8            hamilton  39.1834  -84.5333     10.43        88         100
#
#          Wind Speed Country    Date
# City_ID
# 0              8.64      IS  ['dt']
# 2              2.06      VI  ['dt']
# 4              6.31      MH  ['dt']
# 7              9.26      SJ  ['dt']
# 8              3.09      US  ['dt']

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere = city_data_df[city_data_df['Lat'] <= 0]

# Display sample data
southern_hemisphere.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                           waitangi -43.9535 -176.5597     13.79        98
# 3                          saquarema -22.9200  -42.5103     22.54        92
# 5                          grytviken -54.2811  -36.5092      3.81        81
# 6        posto fiscal rolim de moura -13.0833  -62.2667     23.13        94
# 9                  port-aux-francais -49.3500   70.2167      6.53        95
#
#          Cloudiness  Wind Speed Country    Date
# City_ID
# 1                85        2.24      NZ  ['dt']
# 3               100        6.34      BR  ['dt']
# 5               100        3.90      GS  ['dt']
# 6                99        0.95      BR  ['dt']
# 9               100       18.69      TF  ['dt']

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Define x_values and y_values for Temperature vs. Latitude
x_values_temp_north = northern_hemisphere['Lat']
y_values_temp_north = northern_hemisphere['Max Temp']

# Call the linear regression function for Temperature vs. Latitude
plot_linear_regression(x_values_temp_north, y_values_temp_north, "Max Temp", (10, -30))
# Out:
# The r^2-value is: 0.7278663964799127

# %%
# Linear regression on Southern Hemisphere
# Define x_values and y_values for Temperature vs. Latitude
x_values_temperature = southern_hemisphere['Lat']
y_values_temperature = southern_hemisphere['Max Temp']

# Call the linear regression function for Temperature vs. Latitude
plot_linear_regression(x_values_temperature, y_values_temperature, "Max Temp", (-25, 5))
# Out:
# The r^2-value is: 0.3631239975663753

# %% [markdown]
# Discussion about the linear relationship: While an increase in latitude correlates with an increase in max temperature in both hemispheres, the relationship is much stronger in the northern hemisphere(r^2 = 0.728 vs 0.363). This makes sense considering a much larger portion of the southern hemisphere is dominated by water, which has a moderating effect on the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Define x_values and y_values for Humidity vs. Latitude
x_values_humid_north = northern_hemisphere['Lat']
y_values_humid_north = northern_hemisphere['Humidity']

# Call the linear regression function for Humidity vs. Latitude
plot_linear_regression(x_values_humid_north, y_values_humid_north, "Humidity", (50, 10))
# Out:
# The r^2-value is: 0.06268483837486213

# %%
# Southern Hemisphere
# Define x_values and y_values for Humidity vs. Latitude
x_values_humid = southern_hemisphere['Lat']
y_values_humid = southern_hemisphere['Humidity']

# Call the linear regression function for Humidity vs. Latitude
plot_linear_regression(x_values_humid, y_values_humid, "Humidity", (-22, 10))
# Out:
# The r^2-value is: 0.06720478381566544

# %% [markdown]
# **Discussion about the linear relationship:** The r^2 value is incredibly low in both hemispheres when comparing humidity and latitude. This tells us that there is very little correlation between the two metrics.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Define x_values and y_values for Cloudiness vs. Latitude
x_values_cloud_north = northern_hemisphere['Lat']
y_values_cloud_north = northern_hemisphere['Cloudiness']

# Call the linear regression function for Cloudiness vs. Latitude
plot_linear_regression(x_values_cloud_north, y_values_cloud_north, "Cloudiness", (20, 46))
# Out:
# The r^2-value is: 0.06720380830462659

# %%
# Southern Hemisphere
# Define x_values and y_values for Cloudiness vs. Latitude
x_values_cloud = southern_hemisphere['Lat']
y_values_cloud = southern_hemisphere['Cloudiness']

# Call the linear regression function for Cloudiness vs. Latitude
plot_linear_regression(x_values_cloud, y_values_cloud, "Cloudiness", (-50, 40))
# Out:
# The r^2-value is: 0.0030851071247841077

# %% [markdown]
# **Discussion about the linear relationship:** There is no correlation between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Define x_values and y_values for Wind Speed vs. Latitude
x_values_wind_north = northern_hemisphere['Lat']
y_values_wind_north = northern_hemisphere['Wind Speed']

# Call the linear regression function for Wind Speed vs. Latitude
plot_linear_regression(x_values_wind_north, y_values_wind_north, "Wind Speed", (0, 15))
# Out:
# The r^2-value is: 0.06339704623629065

# %%
# Southern Hemisphere
# Define x_values and y_values for Wind Speed vs. Latitude
x_values_wind = southern_hemisphere['Lat']
y_values_wind = southern_hemisphere['Wind Speed']

# Call the linear regression function for Wind Speed vs. Latitude
plot_linear_regression(x_values_wind, y_values_wind, "Wind Speed", (-50, 15))
# Out:
# The r^2-value is: 0.12664751892940673

# %% [markdown]
# **Discussion about the linear relationship:** The low R^2 in both graphs suggests that latitude is not a good predictor of wind speed. The relationship is not linear, or other factors overshadow latitude's influence on wind speed.
